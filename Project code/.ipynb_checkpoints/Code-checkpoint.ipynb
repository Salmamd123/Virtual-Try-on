# %%
import time
import dlib 
import cv2
from PyQt5 import QtWidgets
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QProgressBar, QLabel, QFrame, QHBoxLayout, QVBoxLayout
from PyQt5.QtCore import Qt, QTimer
import stryon, ntron
from PyQt5 import QtCore, QtGui, QtWidgets

from splashh import SplashScreen
class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(1081, 809)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Fixed, QtWidgets.QSizePolicy.Expanding)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(MainWindow.sizePolicy().hasHeightForWidth())
        MainWindow.setSizePolicy(sizePolicy)
        MainWindow.setIconSize(QtCore.QSize(24, 24))
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setStyleSheet("*{\n"
"color:#000;\n"
"border:none;\n"
"}\n"
"#centralwidget{\n"
"background-color:#eff9fe;\n"
"}\n"
"#leftmenu{\n"
"background-color:#2596be;\n"
"}\n"
"#QLineEdit{\n"
"background:transperent;\n"
"}\n"
"#searchframe{\n"
"border-radius:10px;\n"
"border:2px solid #2596be;\n"
"}\n"
"#appheader{\n"
"color: #2596be;\n"
"}\n"
"#card1,#card2,#card3,#card4{\n"
"background-color:#fefeff\n"
";\n"
"border-radius:25px;\n"
"\n"
"}\n"
"#Tryon1,#Tryon2,#Tryon3,#Tryon4,#Tryon5,#Tryon6,#Tryon7,#Tryon8,#tryon_2{\n"
"background-color:#2596be;\n"
"color:#fff;\n"
"border-radius:10px;\n"
"}\n"
"#widget_7,#widget_5,#widget_4,#label_8{\n"
"background-color:#fefeff;\n"
"border-radius:25px;\n"
"}\n"
"#Glass_1,#Glass_2,#Glass_3,#Glass_4{\n"
"background-color:#fefef;\n"
"border-radius:25px;}\n"
"#Necklace1,#Necklace2,#Necklace3,#Necklace4{\n"
"background-color:#fefef;\n"
"border-radius:25px;}\n"
"\n"
"")
        self.centralwidget.setObjectName("centralwidget")
        self.verticalLayout_4 = QtWidgets.QVBoxLayout(self.centralwidget)
        self.verticalLayout_4.setObjectName("verticalLayout_4")
        self.mainbody = QtWidgets.QWidget(self.centralwidget)
        self.mainbody.setAutoFillBackground(False)
        self.mainbody.setObjectName("mainbody")
        self.verticalLayout = QtWidgets.QVBoxLayout(self.mainbody)
        self.verticalLayout.setObjectName("verticalLayout")
        self.headerFrame = QtWidgets.QWidget(self.mainbody)
        self.headerFrame.setAutoFillBackground(False)
        self.headerFrame.setObjectName("headerFrame")
        self.horizontalLayout_2 = QtWidgets.QHBoxLayout(self.headerFrame)
        self.horizontalLayout_2.setObjectName("horizontalLayout_2")
        self.widget = QtWidgets.QWidget(self.headerFrame)
        self.widget.setObjectName("widget")
        self.horizontalLayout_3 = QtWidgets.QHBoxLayout(self.widget)
        self.horizontalLayout_3.setObjectName("horizontalLayout_3")
        self.menuBtn = QtWidgets.QPushButton(self.widget)
        self.menuBtn.setText("")
        icon = QtGui.QIcon()
        icon.addPixmap(QtGui.QPixmap(":/blueIcons/icons/blue/menu.svg"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.menuBtn.setIcon(icon)
        self.menuBtn.setIconSize(QtCore.QSize(24, 24))
        self.menuBtn.setObjectName("menuBtn")
        self.horizontalLayout_3.addWidget(self.menuBtn, 0, QtCore.Qt.AlignTop)
        self.appheader = QtWidgets.QLabel(self.widget)
        font = QtGui.QFont()
        font.setPointSize(15)
        font.setBold(True)
        font.setWeight(75)
        self.appheader.setFont(font)
        self.appheader.setObjectName("appheader")
        self.horizontalLayout_3.addWidget(self.appheader)
        self.horizontalLayout_2.addWidget(self.widget, 0, QtCore.Qt.AlignLeft|QtCore.Qt.AlignTop)
        self.widget_2 = QtWidgets.QWidget(self.headerFrame)
        self.widget_2.setObjectName("widget_2")
        self.horizontalLayout_6 = QtWidgets.QHBoxLayout(self.widget_2)
        self.horizontalLayout_6.setContentsMargins(0, 0, 0, 0)
        self.horizontalLayout_6.setObjectName("horizontalLayout_6")
        self.acoountbtn = QtWidgets.QPushButton(self.widget_2)
        self.acoountbtn.setMinimumSize(QtCore.QSize(24, 24))
        self.acoountbtn.setMaximumSize(QtCore.QSize(30, 30))
        self.acoountbtn.setText("")
        icon1 = QtGui.QIcon()
        icon1.addPixmap(QtGui.QPixmap(":/blueIcons/icons/blue/user.svg"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.acoountbtn.setIcon(icon1)
        self.acoountbtn.setIconSize(QtCore.QSize(32, 32))
        self.acoountbtn.setObjectName("acoountbtn")
        self.horizontalLayout_6.addWidget(self.acoountbtn, 0, QtCore.Qt.AlignTop)
        self.horizontalLayout_2.addWidget(self.widget_2, 0, QtCore.Qt.AlignRight|QtCore.Qt.AlignTop)
        self.verticalLayout.addWidget(self.headerFrame)
        self.cardsFrame = QtWidgets.QWidget(self.mainbody)
        self.cardsFrame.setObjectName("cardsFrame")
        self.horizontalLayout_7 = QtWidgets.QHBoxLayout(self.cardsFrame)
        self.horizontalLayout_7.setContentsMargins(0, 0, 0, 0)
        self.horizontalLayout_7.setSpacing(20)
        self.horizontalLayout_7.setObjectName("horizontalLayout_7")
        self.card2 = QtWidgets.QFrame(self.cardsFrame)
        self.card2.setMinimumSize(QtCore.QSize(160, 0))
        self.card2.setMaximumSize(QtCore.QSize(16777215, 158))
        self.card2.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.card2.setFrameShadow(QtWidgets.QFrame.Raised)
        self.card2.setObjectName("card2")
        self.verticalLayout_2 = QtWidgets.QVBoxLayout(self.card2)
        self.verticalLayout_2.setContentsMargins(0, -1, -1, -1)
        self.verticalLayout_2.setObjectName("verticalLayout_2")
        self.home = QtWidgets.QFrame(self.card2)
        self.home.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.home.setFrameShadow(QtWidgets.QFrame.Raised)
        self.home.setObjectName("home")
        self.horizontalLayout_8 = QtWidgets.QHBoxLayout(self.home)
        self.horizontalLayout_8.setObjectName("horizontalLayout_8")
        self.label = QtWidgets.QLabel(self.home)
        font = QtGui.QFont()
        font.setPointSize(14)
        font.setBold(True)
        font.setItalic(False)
        font.setWeight(75)
        self.label.setFont(font)
        self.label.setObjectName("label")
        self.horizontalLayout_8.addWidget(self.label)
        self.label_3 = QtWidgets.QLabel(self.home)
        self.label_3.setMinimumSize(QtCore.QSize(40, 40))
        self.label_3.setMaximumSize(QtCore.QSize(40, 40))
        self.label_3.setText("")
        self.label_3.setPixmap(QtGui.QPixmap(":/blueIcons/icons/blue/home.svg"))
        self.label_3.setScaledContents(True)
        self.label_3.setObjectName("label_3")
        self.horizontalLayout_8.addWidget(self.label_3)
        self.verticalLayout_2.addWidget(self.home, 0, QtCore.Qt.AlignTop)
        self.horizontalLayout_7.addWidget(self.card2)
        self.card1 = QtWidgets.QFrame(self.cardsFrame)
        self.card1.setMinimumSize(QtCore.QSize(160, 0))
        self.card1.setMaximumSize(QtCore.QSize(16777215, 16777215))
        self.card1.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.card1.setFrameShadow(QtWidgets.QFrame.Raised)
        self.card1.setObjectName("card1")
        self.verticalLayout_3 = QtWidgets.QVBoxLayout(self.card1)
        self.verticalLayout_3.setObjectName("verticalLayout_3")
        self.tryon = QtWidgets.QFrame(self.card1)
        self.tryon.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.tryon.setFrameShadow(QtWidgets.QFrame.Raised)
        self.tryon.setObjectName("tryon")
        self.horizontalLayout_9 = QtWidgets.QHBoxLayout(self.tryon)
        self.horizontalLayout_9.setObjectName("horizontalLayout_9")
        self.label_5 = QtWidgets.QLabel(self.tryon)
        self.label_5.setMinimumSize(QtCore.QSize(120, 0))
        font = QtGui.QFont()
        font.setPointSize(14)
        font.setBold(True)
        font.setItalic(False)
        font.setWeight(75)
        self.label_5.setFont(font)
        self.label_5.setObjectName("label_5")
        self.horizontalLayout_9.addWidget(self.label_5, 0, QtCore.Qt.AlignLeft)
        self.label_6 = QtWidgets.QLabel(self.tryon)
        self.label_6.setMinimumSize(QtCore.QSize(40, 40))
        self.label_6.setMaximumSize(QtCore.QSize(40, 40))
        self.label_6.setText("")
        self.label_6.setPixmap(QtGui.QPixmap(":/blueIcons/icons/blue/aperture.svg"))
        self.label_6.setScaledContents(True)
        self.label_6.setObjectName("label_6")
        self.horizontalLayout_9.addWidget(self.label_6)
        self.verticalLayout_3.addWidget(self.tryon, 0, QtCore.Qt.AlignTop)
        self.horizontalLayout_7.addWidget(self.card1)
        self.card4 = QtWidgets.QFrame(self.cardsFrame)
        self.card4.setMinimumSize(QtCore.QSize(160, 0))
        self.card4.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.card4.setFrameShadow(QtWidgets.QFrame.Raised)
        self.card4.setObjectName("card4")
        self.verticalLayout_5 = QtWidgets.QVBoxLayout(self.card4)
        self.verticalLayout_5.setObjectName("verticalLayout_5")
        self.contactus = QtWidgets.QFrame(self.card4)
        self.contactus.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.contactus.setFrameShadow(QtWidgets.QFrame.Raised)
        self.contactus.setObjectName("contactus")
        self.horizontalLayout_11 = QtWidgets.QHBoxLayout(self.contactus)
        self.horizontalLayout_11.setObjectName("horizontalLayout_11")
        self.callericon = QtWidgets.QLabel(self.contactus)
        self.callericon.setMinimumSize(QtCore.QSize(40, 40))
        self.callericon.setMaximumSize(QtCore.QSize(46, 40))
        self.callericon.setText("")
        self.callericon.setPixmap(QtGui.QPixmap(":/blueIcons/icons/blue/phone-call.svg"))
        self.callericon.setScaledContents(True)
        self.callericon.setObjectName("callericon")
        self.horizontalLayout_11.addWidget(self.callericon)
        self.contact = QtWidgets.QLabel(self.contactus)
        font = QtGui.QFont()
        font.setPointSize(14)
        font.setBold(True)
        font.setItalic(False)
        font.setWeight(75)
        self.contact.setFont(font)
        self.contact.setObjectName("contact")
        self.horizontalLayout_11.addWidget(self.contact)
        self.verticalLayout_5.addWidget(self.contactus)
        self.horizontalLayout_7.addWidget(self.card4)
        self.verticalLayout.addWidget(self.cardsFrame, 0, QtCore.Qt.AlignTop)
        self.verticalLayout_4.addWidget(self.mainbody, 0, QtCore.Qt.AlignTop)
        self.widget_3 = QtWidgets.QWidget(self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Preferred, QtWidgets.QSizePolicy.Expanding)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.widget_3.sizePolicy().hasHeightForWidth())
        self.widget_3.setSizePolicy(sizePolicy)
        self.widget_3.setAutoFillBackground(False)
        self.widget_3.setObjectName("widget_3")
        self.glasses = QtWidgets.QFrame(self.widget_3)
        self.glasses.setGeometry(QtCore.QRect(0, 0, 791, 291))
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Maximum, QtWidgets.QSizePolicy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.glasses.sizePolicy().hasHeightForWidth())
        self.glasses.setSizePolicy(sizePolicy)
        self.glasses.setAutoFillBackground(False)
        self.glasses.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.glasses.setFrameShadow(QtWidgets.QFrame.Raised)
        self.glasses.setObjectName("glasses")
        self.Glass_1 = QtWidgets.QWidget(self.glasses)
        self.Glass_1.setGeometry(QtCore.QRect(30, 50, 141, 171))
        self.Glass_1.setStyleSheet("#Glass_1,#glasses{\n"
"background-color: rgb(255, 255, 255);\n"
"border-radious:25px;}")
        self.Glass_1.setObjectName("Glass_1")
        self.img1 = QtWidgets.QLabel(self.Glass_1)
        self.img1.setGeometry(QtCore.QRect(0, 10, 140, 141))
        self.img1.setText("")
        self.img1.setPixmap(QtGui.QPixmap(":/blueIcons/glass1.png"))
        self.img1.setScaledContents(True)
        self.img1.setObjectName("img1")
        self.Glass_2 = QtWidgets.QWidget(self.glasses)
        self.Glass_2.setGeometry(QtCore.QRect(190, 50, 141, 171))
        self.Glass_2.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.Glass_2.setObjectName("Glass_2")
        self.img2 = QtWidgets.QLabel(self.Glass_2)
        self.img2.setGeometry(QtCore.QRect(0, 20, 140, 141))
        self.img2.setText("")
        self.img2.setPixmap(QtGui.QPixmap(":/blueIcons/glass.png"))
        self.img2.setScaledContents(True)
        self.img2.setObjectName("img2")
        self.Glass_3 = QtWidgets.QWidget(self.glasses)
        self.Glass_3.setGeometry(QtCore.QRect(370, 50, 141, 171))
        self.Glass_3.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.Glass_3.setObjectName("Glass_3")
        self.img3 = QtWidgets.QLabel(self.Glass_3)
        self.img3.setGeometry(QtCore.QRect(0, 20, 140, 141))
        self.img3.setText("")
        self.img3.setPixmap(QtGui.QPixmap("glass33.png"))
        self.img3.setScaledContents(True)
        self.img3.setObjectName("img3")
        self.glasses_2 = QtWidgets.QLabel(self.glasses)
        self.glasses_2.setGeometry(QtCore.QRect(40, 10, 151, 20))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.glasses_2.setFont(font)
        self.glasses_2.setObjectName("glasses_2")
        self.tryon_2 = QtWidgets.QPushButton(self.glasses)
        self.tryon_2.setGeometry(QtCore.QRect(50, 240, 93, 28))
        self.tryon_2.setObjectName("tryon_2")
        self.Tryon1 = QtWidgets.QPushButton(self.glasses)
        self.Tryon1.setGeometry(QtCore.QRect(220, 240, 93, 28))
        self.Tryon1.setObjectName("Tryon1")
        self.Tryon3 = QtWidgets.QPushButton(self.glasses)
        self.Tryon3.setGeometry(QtCore.QRect(400, 240, 93, 28))
        self.Tryon3.setObjectName("Tryon3")
        self.Glass_4 = QtWidgets.QWidget(self.glasses)
        self.Glass_4.setGeometry(QtCore.QRect(540, 50, 141, 171))
        self.Glass_4.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.Glass_4.setObjectName("Glass_4")
        self.img4 = QtWidgets.QLabel(self.Glass_4)
        self.img4.setGeometry(QtCore.QRect(0, 20, 140, 141))
        self.img4.setText("")
        self.img4.setPixmap(QtGui.QPixmap(":/blueIcons/glass3.png"))
        self.img4.setScaledContents(True)
        self.img4.setObjectName("img4")
        self.Tryon4 = QtWidgets.QPushButton(self.glasses)
        self.Tryon4.setGeometry(QtCore.QRect(560, 240, 93, 28))
        self.Tryon4.setAutoFillBackground(False)
        self.Tryon4.setStyleSheet("#pushButton_4{\n"
"background-color: rgb(0, 150, 195);\n"
"color:white;\n"
"\n"
"border-radius:10px;\n"
"}")
        self.Tryon4.setObjectName("Tryon4")
        self.accessories = QtWidgets.QFrame(self.widget_3)
        self.accessories.setGeometry(QtCore.QRect(0, 280, 791, 271))
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Expanding, QtWidgets.QSizePolicy.Expanding)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(0)
        sizePolicy.setHeightForWidth(self.accessories.sizePolicy().hasHeightForWidth())
        self.accessories.setSizePolicy(sizePolicy)
        self.accessories.setMaximumSize(QtCore.QSize(791, 271))
        self.accessories.setAutoFillBackground(False)
        self.accessories.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.accessories.setFrameShadow(QtWidgets.QFrame.Raised)
        self.accessories.setObjectName("accessories")
        self.Accessories = QtWidgets.QLabel(self.accessories)
        self.Accessories.setGeometry(QtCore.QRect(20, 10, 151, 16))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.Accessories.setFont(font)
        self.Accessories.setObjectName("Accessories")
        self.Necklace1 = QtWidgets.QWidget(self.accessories)
        self.Necklace1.setGeometry(QtCore.QRect(30, 40, 140, 171))
        self.Necklace1.setMinimumSize(QtCore.QSize(140, 171))
        self.Necklace1.setAutoFillBackground(False)
        self.Necklace1.setStyleSheet("#Necklace1\n"
"{\n"
"background-color: rgb(255, 255, 255);\n"
"border-radius:25px;}")
        self.Necklace1.setObjectName("Necklace1")
        self.img6 = QtWidgets.QLabel(self.Necklace1)
        self.img6.setGeometry(QtCore.QRect(0, 20, 140, 141))
        self.img6.setText("")
        self.img6.setPixmap(QtGui.QPixmap(":/blueIcons/necklac1.png"))
        self.img6.setScaledContents(True)
        self.img6.setObjectName("img6")
        self.Necklace2 = QtWidgets.QWidget(self.accessories)
        self.Necklace2.setGeometry(QtCore.QRect(210, 40, 141, 171))
        self.Necklace2.setStyleSheet("#Necklace2{\n"
"background-color: rgb(255, 255, 255);\n"
"border-radius:25px;}")
        self.Necklace2.setObjectName("Necklace2")
        self.img5 = QtWidgets.QLabel(self.Necklace2)
        self.img5.setGeometry(QtCore.QRect(0, 20, 140, 141))
        self.img5.setText("")
        self.img5.setPixmap(QtGui.QPixmap(":/blueIcons/necklace 2.png"))
        self.img5.setScaledContents(True)
        self.img5.setObjectName("img5")
        self.Necklace3 = QtWidgets.QWidget(self.accessories)
        self.Necklace3.setGeometry(QtCore.QRect(380, 40, 141, 171))
        self.Necklace3.setStyleSheet("#Necklace3{\n"
"background-color: rgb(255, 255, 255);\n"
"border-radius:25px;}")
        self.Necklace3.setObjectName("Necklace3")
        self.img7 = QtWidgets.QLabel(self.Necklace3)
        self.img7.setGeometry(QtCore.QRect(0, 20, 140, 141))
        self.img7.setText("")
        self.img7.setPixmap(QtGui.QPixmap(":/blueIcons/necklace 3.png"))
        self.img7.setScaledContents(True)
        self.img7.setObjectName("img7")
        self.Necklace4 = QtWidgets.QWidget(self.accessories)
        self.Necklace4.setGeometry(QtCore.QRect(550, 40, 141, 171))
        self.Necklace4.setStyleSheet("#Necklace4{\n"
"background-color: rgb(255, 255, 255);\n"
"border-radius:25px;}")
        self.Necklace4.setObjectName("Necklace4")
        self.img8 = QtWidgets.QLabel(self.Necklace4)
        self.img8.setGeometry(QtCore.QRect(0, 20, 140, 141))
        self.img8.setText("")
        self.img8.setPixmap(QtGui.QPixmap(":/blueIcons/necklace 4.png"))
        self.img8.setScaledContents(True)
        self.img8.setObjectName("img8")
        self.Tryon5 = QtWidgets.QPushButton(self.accessories)
        self.Tryon5.setGeometry(QtCore.QRect(50, 230, 93, 28))
        self.Tryon5.setStyleSheet("#pushButton_5{\n"
"background-color: rgb(0, 150, 195);\n"
"color:white;\n"
"\n"
"border-radius:10px;\n"
"}")
        self.Tryon5.setObjectName("Tryon5")
        self.Tryon6 = QtWidgets.QPushButton(self.accessories)
        self.Tryon6.setGeometry(QtCore.QRect(230, 230, 93, 28))
        self.Tryon6.setStyleSheet("#pushButton_6{\n"
"background-color: rgb(0, 150, 195);\n"
"color:white;\n"
"\n"
"border-radius:10px;\n"
"}")
        self.Tryon6.setObjectName("Tryon6")
        self.Tryon7 = QtWidgets.QPushButton(self.accessories)
        self.Tryon7.setGeometry(QtCore.QRect(400, 230, 93, 28))
        self.Tryon7.setStyleSheet("#pushButton_7{\n"
"background-color: rgb(0, 150, 195);\n"
"color:white;\n"
"\n"
"border-radius:10px;\n"
"}")
        self.Tryon7.setObjectName("Tryon7")
        self.Tryon8 = QtWidgets.QPushButton(self.accessories)
        self.Tryon8.setGeometry(QtCore.QRect(580, 230, 93, 28))
        self.Tryon8.setStyleSheet("#pushButton_8{\n"
"background-color: rgb(0, 150, 195);\n"
"color:white;\n"
"\n"
"border-radius:10px;\n"
"}")
        self.Tryon8.setObjectName("Tryon8")
        self.widget_6 = QtWidgets.QWidget(self.widget_3)
        self.widget_6.setGeometry(QtCore.QRect(800, 0, 241, 571))
        self.widget_6.setMinimumSize(QtCore.QSize(241, 571))
        self.widget_6.setAutoFillBackground(False)
        self.widget_6.setStyleSheet("#widget_6{\n"
"background-color: rgb(255, 255, 255);\n"
"border-radius:25px;}")
        self.widget_6.setObjectName("widget_6")
        self.gridLayout = QtWidgets.QGridLayout(self.widget_6)
        self.gridLayout.setContentsMargins(0, 0, 0, 0)
        self.gridLayout.setObjectName("gridLayout")
        self.Model = QtWidgets.QWidget(self.widget_6)
        self.Model.setAutoFillBackground(False)
        self.Model.setStyleSheet("")
        self.Model.setObjectName("Model")
        self.glassimgM = QtWidgets.QLabel(self.Model)
        self.glassimgM.setGeometry(QtCore.QRect(0, 0, 251, 261))
        self.glassimgM.setStyleSheet("")
        self.glassimgM.setText("")
        self.glassimgM.setPixmap(QtGui.QPixmap(":/blueIcons/model3.png"))
        self.glassimgM.setScaledContents(True)
        self.glassimgM.setObjectName("glassimgM")
        self.gridLayout.addWidget(self.Model, 0, 0, 1, 1)
        self.Model2 = QtWidgets.QWidget(self.widget_6)
        self.Model2.setAutoFillBackground(False)
        self.Model2.setObjectName("Model2")
        self.neckimgM = QtWidgets.QLabel(self.Model2)
        self.neckimgM.setGeometry(QtCore.QRect(0, 0, 251, 261))
        self.neckimgM.setText("")
        self.neckimgM.setPixmap(QtGui.QPixmap(":/blueIcons/model.jpg"))
        self.neckimgM.setScaledContents(True)
        self.neckimgM.setObjectName("neckimgM")
        self.gridLayout.addWidget(self.Model2, 1, 0, 1, 1)
        self.verticalLayout_4.addWidget(self.widget_3)
        MainWindow.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        self.Tryon1.clicked.connect(self.apply_sunglass_effect_1)
        self.tryon_2.clicked.connect(self.apply_sunglass_effect_0)
        self.Tryon3.clicked.connect(self.apply_sunglass_effect_2)
        self.Tryon4.clicked.connect(self.apply_sunglass_effect_3)
        self.Tryon5.clicked.connect(self.apply_necklace_effect_0)
        self.Tryon6.clicked.connect(self.apply_necklace_effect_1)
        self.Tryon7.clicked.connect(self.apply_necklace_effect_2)
        self.Tryon8.clicked.connect(self.apply_necklace_effect_3)
    def apply_sunglass_effect_1(self):
        
        stryon.cv2.imshow('Sunglass Effect',stryon.image_1)
        stryon.cv2.waitKey(0)
        print("try on2 clicked")
        
    def apply_sunglass_effect_0(self):
        stryon.cv2.imshow('Sunglass Effect',stryon.image_0)
        stryon.cv2.waitKey(0)
        print("try on1 clicked")
    def apply_sunglass_effect_2(self):
        stryon.cv2.imshow('Sunglass Effect',stryon.image_2)
        stryon.cv2.waitKey(0)
        print("Tryon4 clicked")
    def apply_sunglass_effect_3(self):
        stryon.cv2.imshow('Sunglass Effect',stryon.image_3)
        stryon.cv2.waitKey(0)
        print("Tryon3 clicked")
    def apply_necklace_effect_0(self):
        
        stryon.cv2.imshow('Necklace Effect',ntron.image)
        stryon.cv2.waitKey(0)
        print("try on clicked")
        
    def apply_necklace_effect_1(self):
        ntron.cv2.imshow('Necklace Effect',ntron.image_1)
        
        print("try on1 clicked")
    def apply_necklace_effect_2(self):
        stryon.cv2.imshow('Necklace Effect',ntron.image_2)
        stryon.cv2.waitKey(0)
        print("Tryon2 clicked")
    def apply_necklace_effect_3(self):
        stryon.cv2.imshow('Necklace Effect',ntron.image_3)
        stryon.cv2.waitKey(0)
        print("Tryon3 clicked")

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "Virtual Try on"))
        self.appheader.setText(_translate("MainWindow", "Virtual Try on"))
        self.label.setText(_translate("MainWindow", "              HOME"))
        self.label_5.setText(_translate("MainWindow", "      TRY ON"))
        self.contact.setText(_translate("MainWindow", "     CONTACT US"))
        self.glasses_2.setText(_translate("MainWindow", "GLASSES"))
        self.tryon_2.setText(_translate("MainWindow", "Try on"))
        self.Tryon1.setText(_translate("MainWindow", "Try on"))
        self.Tryon3.setText(_translate("MainWindow", "Try on"))
        self.Tryon4.setText(_translate("MainWindow", "Try on"))
        self.Accessories.setText(_translate("MainWindow", "ACCESSORIES"))
        self.Tryon5.setText(_translate("MainWindow", "Try on"))
        self.Tryon6.setText(_translate("MainWindow", "Try on"))
        self.Tryon7.setText(_translate("MainWindow", "Try on"))
        self.Tryon8.setText(_translate("MainWindow", "Try on"))
import resources
    
def showMainWindow():
    splash.close()
    MainWindow.show()

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    splash = SplashScreen() 
    splash.setStyleSheet('''
        #LabelTitle {
            font-size: 60px;
            color: #93deed;
        }

        #LabelDesc {
            font-size: 30px;
            color: #c2ced1;
        }

        #LabelLoading {
            font-size: 30px;
            color: #e8e8eb;
        }

        QFrame {
            background-color: #2F4454;
            color: rgb(220, 220, 220);
        }

        QProgressBar {
            background-color: #DA7B93;
            color: rgb(200, 200, 200);
            border-style: none;
            border-radius: 10px;
            text-align: center;
            font-size: 30px;
        }

        QProgressBar::chunk {
            border-radius: 10px;
            background-color: qlineargradient(spread:pad x1:0, x2:1, y1:0.511364, y2:0.523, stop:0 #1C3334, stop:1 #376E6F);
        }
    ''')
    splash.show()
    timer = QtCore.QTimer()
    timer.timeout.connect(lambda: showMainWindow())
    timer.start(11000) 
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    
    sys.exit(app.exec_())
# Out:
# try on2 clicked
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
